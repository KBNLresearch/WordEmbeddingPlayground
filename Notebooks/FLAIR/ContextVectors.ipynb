# %% [markdown]
# ## Flair Experiments
#
# Use Fair to study context vectors of specific words.

# %%
from utils import *
import numpy as np
import os
from tqdm import tqdm_notebook
from collections import defaultdict
from flair.embeddings import FlairEmbeddings, DocumentPoolEmbeddings#, BertEmbeddings
from flair.embeddings import StackedEmbeddings
from flair.data import Sentence
import pandas as pd
from mpl_toolkits.mplot3d import axes3d, Axes3D
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import random
from glob import glob
from collections import defaultdict

# %% [markdown]
# ## Token Embeddings

# %%
path2range = lambda x: x.split("_")[-1].split(".")[0]
# Out:
# '1870-4'

# %%
pattern = r'\bvrouwelijk'
regex = re.compile(pattern, re.I)
sents2year = {}

for path in glob("./data/kranten_pd_18*.zip"):
    iterator = SentIterator(path,tokenized=False,sample_docs=10000)
    sents2year[path2range(path)] = [s for s in tqdm_notebook(iterator) if regex.findall(s)]
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
for k,v in sents2year.items():
    print(len(v))
# Out:
# 1719
# 2076
# 1584

# %%
flair_forward_embedding = FlairEmbeddings('nl-forward')
flair_backward_embedding = FlairEmbeddings('nl-backward')

# %%
# now create the StackedEmbedding object that combines all embeddings
stacked_embeddings = StackedEmbeddings(
    embeddings=[flair_forward_embedding,flair_backward_embedding])

# %%
tokencontext = defaultdict(list)
labels = []
context = 3
for period, raw_sents in sents2year.items():
    for raw_sent in tqdm_notebook(raw_sents[:100]):
        sentence = Sentence(raw_sent)
        stacked_embeddings.embed(sentence)
    
        # now check out the embedded tokens.
        for i,token in enumerate(sentence):
            if "vrouw" in token.text:
                labels.append(' '.join([sentence[i].text for i in range(max(0,i-context),min(len(sentence),i+context+1))]))
                tokencontext[period].append(np.array(token.embedding))
# Out:
# HBox(children=(IntProgress(value=0, max=97), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))

# %%
tokencontext.keys()
# Out:
# dict_keys(['1870-4', '1875-6', '1860-4'])

# %%
X = np.concatenate([v for k,v in tokencontext.items()],axis=0)
print(X.shape)
# Out:
# (280, 4096)

# %%
names2colors = {n:c for n,c in zip(tokencontext.keys(),["r","b","g"])}
names2colors
# Out:
# {'1870-4': 'r', '1875-6': 'b', '1860-4': 'g'}

# %%
tsne = TSNE(n_components=2, random_state=0,metric='cosine')
X_2d = tsne.fit_transform(X)

# %%
fig = plt.figure(figsize = (30,50))

i = 0

for k,v in tokencontext.items():
    for j in v:
        
        plt.scatter(X_2d[i, 0], X_2d[i, 1],c=names2colors[k])
        plt.annotate(labels[i], (X_2d[i, 0], X_2d[i, 1]),size=14)
        i+=1
    
    
plt.show()
fig.savefig("context_vectors.pdf", bbox_inches='tight')

# %%
for period, raw_sents in sents2year.items():
    for raw_sent in raw_sents[:200]:
        print(raw_sent+"\n")
# Out:
# voor de betrekking van huli t v dekw ij kb aan de burgerschool alhier de rereisehteo zijn behalve de acte ven bevoegdheid als hulponder viieres eem i vrouwelijke baodwerken de jaarwedde bedraagt oo
#
# in de gevangenis van jeugdige vrouwelijke veroordeelden te montfoort bevindt zich een meisje veroordeeld tot vijf jaren gevangenisstraf
#
# in newyork is een bankiershuis opgerigt aan welks hoofd eene dame staat terwijl alle bedienden van het vrouwelijk geslacht zijn
#
# blijkens de resultaten der jongste telling van de bevolking te petersburg gevestigd is het aantal zielen thans geklommen tot tot het mannelijk geslacht behooren tot het vrcuwclijk inwoners
#
# men zal zich eene voorstelling kunnen vormen van de benarde positie der passagiers maar tevens van de algemeene vreugde toen het bleek dat met uitzondering van een mannelijken reiziger geen van allen eenig belangrijk letsel had bekomen
#
# j boeschi mannelijk oud j
#
# a floris mannelijk oud j
#
# mannelijke kinderen laat hij niet na
#
# duid der vrouwelijke nieuwsgierigheid eene misschien onbescheidene vraag niet ten kwade mjjnheer
#
# in newyork is een bankiershuis opgericht aan welks hoofd eene dame staat terwijl allo bedienden van het vrouwelijk geslacht zijn
#
# omdat men den officieren vau het indische leger van tijd tot tijd verlof moet geven om hier hunne gezondheid te herstellen en omdat zij slechts jaar behoeven te dienen zoodat zij in de volle kracht van den mannelijkeu leeftijd even over hun veertigste jaar hier reeds met een hoog pensioen komen leven
#
# het londensch exemplaar is van het vrouwelijk geslacht heet jenny en beeft innige ivrieadscbap gesloten met een jongen haan dit aan boerd van hetzelfde schip was en die thans met jen njdexelfdekooi bewoont
#
# na bare echlverbindtenis staakte zjj haren arbeid in de mjjnen en leefde van bezembindendrivntwintig jaar later stierf de vrouw van dezen man en de vrouwelijke weduwnaar vmid ten laatste in een tweede gemalin troost voor het onherstelbare verlies
#
# december bedroeg de bevolking van t pruisisch koninkrijk inwoners waarvan tot het mannelijk en tot het vrouwelijk geslacht behoorden
#
# de vrouwelijke bemoeial blijspel in taf
#
# de vrouwelijke bemoeial
#
# de vrouwelijke bemoeial
#
# klimaat en kwaadwilligheid hadden zamengewerkt offl deze groote expeditie geheel te vernietigen en wij moeten i de zeldzame wilskracht en de mannelijke volharding bewonderen en vereeren van de jeugdige teedere vrouw die niettegenstaande alle tegenwerking bezwaren en hinderpalen niettegenstaande de grootste ontberingen en ongemakken waarmede zij te kampen had toch bleef voortstreven naar de bereiking van haar doel tot dat een te groote
#
# in de gisteren avond alhier geboudene vergadering van het departement der maatschappij tot nut ran algemeen voor buren en omstreken ten huize van de kindenn beekman trad de heer schliinmer rector aan de latijnsche school te tiel als spreker op en had tot zijn onderwerp gekozen eenige schetsen uit het vrouwelijke tevm benevens eene bijdrage getiteld papa s verjaardag of vader perkman
#
# e vrouwelijke bemoeial blijspel in af
#
# hulmd rwyi rs en in de vrouwelijke hand itaal de kransene hoog
#
# te zurich studeren op dit oogenblik vrouwelijke studenten in de medicijnen terwijl eenige jaren geleden slechts eene enkele dame zich daar bevond
#
# te berlijn heeft zich dezer dagen een vrouwelijke tandmeester gevestigd en ofschoon we dit wel wat al te mannelijk vinden blijkt er toch uit dat het chirurgicale vak veel aantrekkelijks voor het zachtere zwakkere gedeelte vai het menschdom bezit
#
# albregt en van olleffen de vrouwelijke bemoeial
#
# albregt en van olleffeo de vrouwelijke bemoeial
#
# zijn goede smaak en fijne manieren om niet te spreken van mannelijk gevoel en edele beginselen dau niet meer te viaden in het babyion der nieuwere tijden zooals da costa parijs noemde
#
# neen met uitzondering van het journal des dbats heeft zoover als wij hebben opgemerkt geen dagblad deze edelmoedige mannelijke ridderlijke daad der moderne republikeinen aan het volk voorgesteld in al haar wansmaak en ruwheid
#
# er zijn namelijk mannelijke en vrouwelijke stammen
#
# oe mannelijke stammen bebben bloesems die slechte met meeldraden zijn voordien en een druif vormen welke voor de rgpbeid van het zaad in een bekleedsel de zoogenaamde bloenucheeje gehuld is
#
# de vrouwelijke stammen daarentegen hebben vroehtbmzen welke eveneens door eene blocmscbeede ingesloten zich echter niet ontwikkelen kunnen wanneer het zaad of de stof der meeldraden baar nietbovruchten
#
# om dez bevruchting te verzekeren zen der een te groot aantal onproduktive mannelijke bo men te planten klimmen de arabieren tegeo den bloeitijd in de maand april ia da vrouwelijke omhoog en steken in de btoemsefceede een niet mannelijke bloesems beladen stengeltje welks meeldraden de jonge vrochibuizen bevrachten dan zwellen da vruchten worden vleeschig en vormen grooie druiven welker gewigt somtijds van totq kilo bedraagt
#
# laatste voorstelling door het tooneelgezelschap van den botterdamsehen schouwburg directie albregt en van ollefen be vrouwelijke bemoeial blijspel in taf
#
# albregt en van ollefte de vrouwelijke bemoeial
#
# wij mogen dien zegen niet lijdelijk blijven afwachten wij moeten ons dien waardig maken door te handelen door te handelen met verstand met mannelijke vastberadenheid wij mogen niet toegeven aan zwakheid en ontmoediging
#
# zoolang mannelijke moed en volharding verachting van overmacht pijnen vonden dood en doodsgevaar zelfopoffering en drieste dapperheid in s mensehen borst nog een gevoelige snaar vinden zullen verhalen als dit rapport die snaar doen trillen van ontroering
#
# evenzeer als zij er mede was geopend werd deze fraai geslyleerde lezing door eeno kleine philippica besloten nu gcrigl aan int adres van den amsterdainschcn gemeenteraad over zijn bekend besluit tot mietoprigting van cene school voor middelbaar onderwijs voor meisjes een besluit dat molire die wel streed tegen de femmes savant es maar geenszins tegen wezenlijke vrouwelijke beschaving volgens spreker niet weinig zou hebben gehekeld
#
# voor personen van het vrouwelijk geslacht is bij de vrouw van den directeur een geheel afzond rlijk kantoor
#
# ik meen natuurlijk zonder courant want de andere vrouwelijke organen zullen zij blijven behouden met of zonder jufvrouw perk of deu uitgever van dijk
#
# dit moge een onbelangrijk feit schijnen doch loont het niet welke geestkracht behoefte aan mannelijke inspanningen volharding mannen hebben die als gladstone de wereld verbazen door al hetgeen zij tot stand brengen en die tijd vinden wetenschappelijke en letterkundige boeken te schrijven in hetzelfde jaar dat zij belangrijke wetten voorbereiden en doen aannemen in het huis der gemeenten en als minister het land regeren
#
# l let meest de vu ksguusl genietende middel ter genezing v ui vrouwelijke kwalen
#
# gevaccineerd werden personen van het mannelijk en van bet vrouwelijk geslacht handel en scheepvaart waren minder levendig hetgeen is toe te schrijven aan de omstandigheid dat tengevolge van de onveiligheid der reeden van boeleleng en sangsit de vaartuigen alln ter reede van tamoekoes teboenkoes konden anrekeu
#
# men wenscht te koopen een fi airijliond n of hoogstens twee veld geloopen hebbende goed staande apporterende onder appl verdere vereischten zijn mannelijk geslacht kloek yan bouw vlug ter been
#
# albregt en tan olieden de vrouwelijke bemoeial
#
# vrouwelijke bemoeial
#
# zie in de liefde ir het huwelijk in het schoone proces der instandhouding van de schepping hoe het vrouwelijk geslacht eene andere rol heelt dan het mannelijke en hoe toch beiden samenwerken tot hetzelfde doel
#
# hollowtvs pillen en zalf liet meest de volksgunst genietende middel ter genezing van vrouwelijke kwalen
#
# voor personen van het vrouwelijk geslacht is bij de vrouw van den directeur een geheel afzonderlijk kantoor
#
# de gewetens der mannen di op deze punten ongevoeliger zjjn dan die der vrouwen bobben noodig wakker geschud te worden eu hiertoe zijn de krachtige steoten dle het gevoeliger vrouwelijk gemoed geeft onontbeerlijk in zaken van bestuur had men de spoor noodig en oordeelde mr stuart mill ele vrouwen waren volkomen berekend voor het toedienen vaa dergelijken prikkel
#
# hij heeft een gevoel van fierheid in het hart dat hem noopt de leden zijner familie vooral de vrouwelijke te vereledigea tegen eiken aanval
#
# de eea eeuw als deze gewesten haar zoo lang toebehoorend roekeloosheid niet zoo ver drijven om dien gevaarlijk greep te doen in mohammed s leer en als men nu de engelsch wetgeving op het pi ler nalatenschappen vergelijkt met de mohammedaansol dan zal men in beide zekere neiging tot bevoorregting a den jegens het mannelijk oir in de eerste ten op van den eerstgeboren zoon in de laatste ten opzigte de mannelijke spruiten in het algemeen
#
# mei aanstaande op welk tijdstip de beschrijvingsbiljetten aan de woningen der ingezetenen en aan de afgezonderd gedeelten van woonhuizen bedoeld bij artikel der genoemde wet op de personele belasting geene uitgezonderd bezorgd en acht dagen later opgehaald zullen worden in dier voege dat de wederinzameling uiterlijk op den dier maand zal geindigd zijn dat de aanslagen op de voljaarskohieren invorderbaar zijn in tien gelijke termijnen terwijl indien de aanslagen naar tijdsgelang slechts over een kwartaal loopen ze dadelijk in hun geheel moeten betaald worden dat tegenschatters van de zijde der belastingschuldigen door het collegio van dagelijksch bestuur zijn benoemd c j marijnen j wagemakers j schoenmakers en j dielemans dat de aandacht dar ingezetenen in het bijzonder wordt gevestigd op de wijziging welke eene der vrijstellingen van vrouwelijke bedienden bij artikel der wet van deu
#
# voor personen van het vrouwelijk geslacht is bij de vrouw van den directeur een geheel afzonderlijk kantoor
#
# den november zal bet vijfhonderd jaren geleden zijn dat met kasimir den groote van polen de mannelijke lijn van het huis piast uitstierf en de kroon van bet rijk der sarmaten van een erfelijke kroon een kenrkroon werd hetgeen tevens polens verval in zich sloot en dat timurleuk tamerlan de bedwinger der volkeren zich opwerpende tot khan van de dschagata zijne alleenheerscbersloopbaan begon
#
# de vereischten zijn behalve de acte van bevoegdheid als hulponderwijzeres eene acte voor vrouwelijke handwerken
#
# d c specht vrouwelijk oud jaren
#
# troostend en helpend stond zij aan zljn ziekbed verligtte hem zijne eenzaamheid en vervulde een echt vrouwelijken pligt zij het dan ook onder buitengewone omstanddigbeden
#
# in nieuwyork is een bankiershuis opgerigt aan welks hoofd eene dame staat terwijl alle bedienden van het vrouwelijk eslacht zijn
#
# vrouwelijke kwalen
#
# de heer ii oj e r trok daarna op krach tigen mannelijken toon te velde tegen deze
#
# le noir ware dan de held des volks geweest die iv prins pierre bet booze bonapartistisch beginsel gedood had een groot burger een martelaar voor de vrijheid een burlus een mannelijke charlotte corday lange de t assassinat
#
# te herkennen hot vele hakzaza s ontmoet men otj lav vooral ia de residentie kediri die geheel omzet zijn met zulk doodshoofden imandaj aanschouwd men ze niet voor gesteld met zware vrouwelijke borsten
#
# bovenlanden in het belang der wetenschap over cjdoeisme heeft onderzocht de wegen en liet vervoer j daar slecht maar het wemelt er van kramats en ij natuurlijke steenen of palen die men zoo gevoev fung t het zinnebeeld der mannelijke natuur en ijeppingskraeht zoude kunuen noemen verder een aanlis keilige rol of bergsteenen waaraan geofferd word iet alleen maar waaraan ook een boekdeel tuiende nonsens r rerbonden
#
# voorafgegaan door de weeskinderen de heeren regenten van het weeshuis en gevolgd door de leden der vincentius vereeniging en die der sociteit st jan een tal van rijtuigen waarin de familie en vrienden des overledenen en verder eene onafzienbare menigte belangstellenden naderde de lijkstoet het kerkhof van waar onder het zingen van een statig de projundis door het zangkoor der st eusebiuskerk het mannelijk personeel van genoemde firma bunker zijnen beminden en te vroeg door den dood ontrukten chef ter laatste rustplaats droeg
#
# de geheele bevolking bestond op dat oogenblik uit n mannelijke inboorlingen meestallen waren gewa mei p jl en boog lans en schild
#
# hij vergeleek frankrijk bij den romeinschen jongeling der oudheid ter wiens eere de familie feestvierde als hij den toga van den mannelijken leeftijd mogt dragen
#
# hoe het zij deze martinus van der hoeven is zonder mannelijke kracht zonder vastheid van karakter zonder zin en moed voor de daden des levens deze geest is zwak ellendig verwijfd bijna deze man is een valsche kluizenaar een onechte mysticus een onechte
#
# ook in dit opzigt werkt de wettelijke beperking tegen haar doel in want terwijl zij de werkuren vermindert vermeerdert zij het aantal kinderen dat de fabrikant behoeft of bij gebreke van kinderen dat der vrouwelijke arbeiders
#
# wat men uit de engelsche rappor ten over de zeden der fabriekmeisjes en vrouwen verneemt toont zeer duidelijk aan dat de fabriek voor de vrouw bovenal eene slechte leerschool is en dat elke maatregel die strekt om de vrouwelijke fabriekbevolking te doen toenemen eene zeer bedenkelijke zijde heeft
#
# aauvaaklf m ulj fe fe sli hellen tot de rechterzijde feta hrit m den dif b te v tot die de overhelt ot het gewicht vaii aen bln u stok helt av de linkerzijde en zin mannelijke ve klarin dat regeering geen pfgejeeje cand daten hebben wil dese nseert de partijen en doet de vrienden van orde ei vrijheid alleen juichen die tevreden zijn dat de moedig raan ontkomt aan de gevaren die hein rechts en linl j dws v met vaste schreden op zijn doel kan afgaan
#
# hoeveel leerlingen zoowel mannelijke als vrouwelijke beneden de jaar in de eerste dagen van december eene door de onderwijzers bestuurde avond zondagsof herhalingssehooi bezoeken zonder op de schoollijst voor gewoon lager onderwijs te zijn ingeschreven
#
# bdrgemeebteh m vi bthoudbbb ran pranek roepen bij deie bolliottanten op voor ie vacant betrekking ven hulpos derwijzrreb au de bnrgereel i alhier de vereisohten lijn behalve de ante van be voegdheid ala hulponder ijaeret eene eete voor vrouwelijke handwerken
#
# zwaardzijde om de mannelijke en van spil ij d e of spinrok ij d e om de vrouw olijke lijn aan te duiden
#
# met de hoedanigheden dezer vijf heeren be keud zouden zijn vier van hen zijn waardige representanten van onzen handeisstand terwijl de vijfde door zijne eigenaardige be ttekkine bij een onafhankelijk mannelijk karakter ook abzius bevoegd is om een d iepen blik in de groote koloniale vraagpunten te werpen en dus evenzeer alle aau
#
# del itten kwam de vergadering tot om ie re oluticn van welk jende de oornaamste zijn hel onderwijs der vrouwelijke jeugd ci lit dringend verbetering en uitbreiding dit kan liet best vi kregen worden door itel oprigten van hoogere bnrgerleien vooi meisjes met vijfjaren cursus zulk eene school moet op a dere grondslagen usten dan icne dergelijke o
#
# vooral wordt van de vrouwelijke handwerken veel werk gemaakt zoo als naaijeu breijen stoppen verstellen bnijden van vrouwenkleederen en lijnwaad
#
# men heeft ook eene school tot vorming van vrouwelijke zetters opgerigt
#
# van te lang levenden behoorden tot het mannelijk en tot het vrouwelijk geslacht gevallen worden toegeschreven aan zwaarmoedigheid ziekte gebrek enz
#
# wanneer wij het in ons land slechts uiterst zelden zien gebeuren dat bekwame juristen die den eersten tyd hunner mannelijke jaren datbekwa
#
# het is eenige geduchte waarheden gezegd betreffende de fransche lichtzinnigheid en oppervlakkigheid en heeft de vooroordeelen bestreden welke de fransche burgers beletten op vrije en mannelijke wijze hunne sociale plichten te vervullen
#
# heeft de gedachte het ongeluk van te moeten antwoorden ik behoor tot het vrouwelijk geslacht dan is alles mis en heeft zjj niet de minste kans want in ons land is men overtuigd dat de vrouwen slechts poppen zijn geschikt om te coqnetteeren en behaagziek te zjjn doch m wier hoofd geen gezonde gedachte kan opkomen
#
# laeter jftist de ondergetcekende vihjhheeft de eer zichv bij bet geacht publiek te recommanderen tot i het vervaardigen van vrouwelijke tot liet geven van onderligt daarin en in de eerste beginselen der piano tegen zeer billijke conditin
#
# oo zijnde inden onzer broederschap meer dan die van eeuig ander verband in staat hetgeen hierboven is aangevoerd ernstig loyaal en mannelijk te bespreken
#
# in het genoemde jaar werden te londen geboren kinderen van het mannelijke van hel vrouwelijke geslacht te zamen kinderen en stierven er personen van het mannelijke en van het vrouwelijke geslacht te zamen personen
#
# de bevolking bedroeg in het midden des jaars mannelijke vrouwelijke in het geheel inwoners
#
# bevattende eene beknopte doch duidelijke beschrijving van de fraaiste en nuttigste vrouwelijke handwerken
#
# handleiding om spoedig en grondig vrouwelijke handwerken te leeren als breijen naaijen haken en stoppen
#
# zij vragen waarborgen tegeii verraad en verrassing en terwijl een onafhankelijke geest zich dus vormt onder de hooge geestelijkheid biedt het katholieke volk van beieren de burgerrechten van mnchen aan dr dllinger om hem te danken voer de mannelijke wijze waarop deze orthodoxe theoloog de aanspraken des pausen op onfeilbaarheid heeft vernietigd
#
# dit moge een onbelangrijk feit schijnen doch toont het niet welke geestkracht behoefte aan mannelijke inspanning en volharding mannen hebben die als gladstone de wereld verbazen door al hetgeen zij tot stand brengen en die tijd vinden wetenschappelijke en letterkundige boeken te schrijven in hetzelfde jaar dat zij belangrijke wetten voorbereiden en doen aannemen in het huis der gemeenten en als minister het land regeeren de speculatiegeest maakt in onze eeuw natuurlijk gebruik van deze heldenaanbidding der menigte van deze vulgaire of welgemeende nieuwsgierigheid om alles te weten van de groote mannen van zijn land en hen te zien
#
# een weekblad voor de vrouwelijke emancipatie zou amusanter geweest zijn
#
# vrouwelijke modisten en naaisters zondag febr u
#
# men naagfilsi jaren oud ervaren in het naaijen en andere vrouwelijke handwerken bekend met de fransche taal enz eene plaats bij kinderen of in eenen winkel
#
# industrieschool voor vrouwelijke jeugd
#
# bet dieitbodekkastoor op de varkenmarkt c g tfi utrecht voor alle manne en vrouwelijke dienstboden is dagelijks geopend
#
# daarbij heeft men in engeland zeer wel ingezien dat de verschijning van mannelijke coryphaen en danseurscavaliers masculinigeneris volstrekt niet bevorderlijk zijn aan het graciedse
#
# vou herman n linde nog een woord heeft gecproken heeft hij reeds de harten zqnrr hoordeietsen gewonnen ij zijn medegesleept door zijn mannelijk schoon etjae sprekeaie doakare oogan
#
# aan zijne vrouwelijke dienstboden die nog niet gehuwd zijn geeft hij bovendien den raad liever verstandig ongehuwd te blijven dan dom te trouwen
#
# het getal geborenen bedroeg van het mannelijk van het vrouwelijk geslacht dat der overledenen van het mannelijk van het vrouwelijk geslacht
#
# m emjs welke zich voorzien willen va bh dlexstboden directofntf bbk bbbl wei vervoesen zich aan nottsleljs in w l kantoor voor mannelijke en vrowt mmm i welijkedienstbodenjivsi s sti
#
# die bewaarschool verbonden aan de lagere school waar het kind spelende leert litf st onder vrouwelijke leiding
#
# het getal geborenen bedroeg van het mannelijk van het vrouwelijk geslacht dat der overledenen van het mannelijk van het vrouwelijk geslacht
#
# ook zegt de correspondent dat de gravin de taak heeft de spanjaarden aan eene vrouwelijke regeering te gewennen voor het geval alphonsus afstand doen oi sterven mocht omdat zij dan in zijne rechten treden zou
#
# haitoob van mannelijke en vrouwelijke dienstboden hoek o ppert van b
#
# het voorstel werd vooral bestreden door den heer b resfordhope die tot de vergadering de vraag rigtte of het niet veel beter was eene enkele florence nightingale of eene enkele mary stanley te bezitten dan een onbeperkt aautal vrouwelijke doctoren die met moeita ha ren weg zouden moeien zoeken tusschen hare mannelijke collega s door
#
# levenloos geboren den lon een kind van mannelijk gesl
#
# ten bewijze dat de zucht om zich aan den onderwij zersstand te wijden ondanks de verhoogde jaarwedden die aan hoofd en hulponderwijzers zijn toegekend in deze streken niet groot is moge ook de mededeeling dienen dat zich van de mannelijke en vrouwelijke adspiranten naar eene acte van bekwaamheid of naar eene aanteekening op reeds verkregen acte in het eerste district van gelderland slechts vijf candidaten naar een hulponderwijzersacte hebben aangemeld
#
# v v c k i j tiv miss emily faithfull de oprigtster der slechts met vrouwelijke krachten
#
# aan de openbare school in de buurtschap daarle gemeente hellendoorn kan geplaatst worden een bekwaam en gechikt kweekeling mannelijk of vrouwelijk tegen genot eener toelage van f per jaar
#
# de mannelijke en vrouwelijke leden der door zijn zeereerw
#
# wellicht overdrijft men de geestdrift voor dergelijke mannelijke spelen tegenwoordig wel een weinig in engeland doch de overdrijving moet niemand blind maken voor de werkelijke schoonheid en het groote nut der athletische spelen reeds door de grieken geliefd
#
# hedenmorgen is uit het rokin een lijkje van een pas geborenkind van het vrouwelijk geslacht opgehaald dat reeds in staat van ontbinding verkeerde
#
# f f tot het afleggen van examen voor lager onderwijs hebben zich tegen de voorjaarszittiug iv het xiiie schooldistrict van noordbrabant aangegeven zoo mannelijke als vrouwelijke candidaten
#
# holloway s pillen zijn niet te evenaren om hunne zuiverende openende eu versterkende eigenschappen zij verdrijven gebrekkige spijsvertering kloppingen en hoofdpijn en zijn bijzonder dienstig in ongesteldheden der vrouwelijke sekte eigen
#
# voegt er bij dat de mannen zoo goed als geen baard hebben een paar haartjes op bovenlip en kin dat is alles en hun uiterlijk voldoet in t geheel niet aan uwe begrippen van mannelijke kracht
#
# gedurende het concilie had z h de mannelijke deugden en de grondige wetenschap harer bisschoppen zoo weinig in europa bekend bewonderd en vormde toen het plan een hunner tot de hooge waardigheid van het cardinalaat te verheffen
#
# tot het geven van onderricht in de twee bovengenoemde vakken wordt iemand gevraagd die bewijzen van kunde en bekwaamheid bezit omdfe aan vier kinaeren van het vrouwelijk geslacht uit den deftigen stand te onderwijzen
#
# bij zulk een getal zegt bedoelde kastelein en in zulk een zaak moet er orde en tucht heerschen daarom houdt hij eiken avond ten ure appl vervolgens houdt hij bij het mannelijk en zijne ega bij het vrouwelijk personeel inspectie of allen zich wel behoorlijk ter ruste hebben begeven s morgens vroeg wordt ieder bij name weder opgeroepen en moeten allen present zijn
#
# zrj dankte god voor dat gelukkige oponthoud en verzadigde haar oogen met den aanblik vau dat ernstige mannelijke gelaat
#
# daarvan zijn van t vrouwelijk en van t mannelijk geslacht
#
# neemt dagelijks inschrijvingen aan van alle mogelijke miei vrouwelijke dienstboden ter bezorging van eene diensts naar alle plaatsen van ons land gelegenheid
#
# de bevolking der groote strafgevangenis te leeuwarden bestond op liet einde des vorigen jaars uit mannelijke gevangenen zijnde minder dan op het einde van
#
# van deze zijn ongeveer mannelijke en ruim vrouwelijke orden en congregatin
#
# j quispel geboren te dordrecht een eervolle vermelding toegekend door de leeraren der sorbonne afdeeling vrouwelijk middelbaar onderwijs voor een letterkundig opstel op het concours dij het einde van den cursus
#
# o die vrouwelijke list
#
# ook zegt de correspondent dat de gravin de taak heeft de spanjaardu aan eene vrouwelijke regering te gewennen voor het geval alphonsus afstand doen of sterven mogt omdat zij dan in zijne regten treden zou
#
# jonkheer johan rabo vankeppel is met alle zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als gerechtigd tot het voeren der titels van baron en van baronnes
#
# zij verdrijven gebrekkige spijsvertering kloppingen en hoofdpijn en zijn bijzonder dienstig io ongesteldheden der vrouwelijke sekte eigen
#
# hoe een mannelijk tfei
#
# maar een plotseling gevoel van vrouwelijke waardigheid was over haar gekomeu
#
# vrouwelijke ambtenaren o
#
# vrouwelijke ambtenaren zijn in vele landen aangesteld bij post en telegrafie
#
# het zou kunnen zijn dat het wachtwoord geheim een beteekenende rol speelde in het nietaanstellen van vrouwelijke ambtenaren bij post en telegrafie
#
# ik wer seh verder niet uil ir wijden maar wil alleen het mannelijk geslaehl opmerkzaam maken op je gebeurtenissen van don dag
#
# naar men verneemt heeft gisteren in het huis van burgerlijke en militaire verzekering alhier eene poging tot ontvlugting door middel van braak plaats gehad door drie crimineel veroordeelde mannelijke gevangenen
#
# laat ieder eendrachtig medewerken tot het verkrijgen van een krachtig intelligent nationaal leger en zij de leus daarbij niet de verbitterende en mismoedige leus van vrees voor annexatie maar wel do mannelijke en waardige van liefde voor onze onafiiankelijkheidjrucbt tot eerlijke handhavingoazor neutraliteit
#
# do raad nam daarna bij acclamatie aan het voorstel van het dagelijksch bestuur om eene proef te nemen met vrouwelijk hulppersoneel op de openbare scholen
#
# hieraan is t toe te schrijven dat het volk van haar veel om niet te zeggen alles verdraagt zij t nooit zoo gortig kunnen maken dat ook de laatsten harer hovelingen ten minste die van het mannelijk geslacht haar den rug toekeeren
#
# het voorstel werd vooral bestreden door den heer berefordhope die tot de vergadering o a de vraag richtte of het niet veel beter was eene enkele florence nightingale of eene enkele mary stanley te hebben dan een onbeperkt aantal vrouwelijke doctoren die met moeite haren weg zouden moeten zoeken tusschen hare mannelijke collega s door
#
# de gemeenteraad van rotterdam heeft bij acclamatie een voorstel aangenomen om aan de volksscholen vrouwelijk hulppersoneel aan te stellen
#
# in de eergisteren door het engelsche lagerhuis gehouden zitting is een do r cowper temple ingediend wetsontwerp waarbij aan de hoogescholen van schotland de bevoegdheid wordt verleend ook aan vrouwelijke personen den doctorsgraad te verleenen in tweede lezing met tegen stemmen verworpen
#
# hyacinth wendde zien onthutst en verwonderd om en toen zag zij het gelaat van haar beminde en begreep door haar vrouwelijk instinct wat er nu volgen zou
#
# aan zijne vrouwelijke dienstboden die nog niet gehuwd zijn geeft hij bovendien dn
#
# in de jongste zitting van het lagerhuis is een door den heer cowper temple ingediend wetsontwerp waarbij aan de hoogescholen van schotland de bevoegdheid wordt verleend ook aan vrouwelijke personen den doctorsgraad te verkenen in tweede lezing met tegen stemmen verworpen
#
# is niet jaren achtereen geconstateerd dat zij te xias minstens een tal kinderen van het mannelijk geslacht opkochten om te dienen tot de schandelijkste doeleinden
#
# de loerah sidik genaamd vermeende dit verzoek niet beter te kunnen opvatten dan door de ter bewaking achtergebleven mannelijke bewoners te doen aanzeggen dat zij het huis en de kampong dadelijk verlaten moesten zoodat alleen eene waschvrouw overbleef die niet begreep wat de reden daarvan zijn kon doch er ging een licht op toen zij des morgens ontwakende bemerkte dat door middel van onderoravin een gaat in den grond aanwezig was waaroor de dieven na kast en kisten te hebben opengebroken
#
# mannelijk j t dochtertje van h klein overmeen maanden
#
# hoe een mannelijk persoon het land had en een vrouwelijk wezen van naam veranderde
#
# er wordt gevraagd een mannelijke dienstbode niet boven jaar oud die goed kan rijden en tevens kan melken
#
# de bevolking vermeerderde dat jaar met liet getal geborenen bedroeg van het mannelijk s van liet vrouwelijk geslacht dat der overledenen van het mannelijk vau liet vrouwelijk geslacht
#
# men vond daarin portretten van den keizerlijken prins van den keizer en de keizerin afbeoldingen van het feest van maart van s keizers begratenis allegorische photographien photographien met redevoeringen en zelfs carte de visito van mannelyke en vrouwelijke agenten
#
# in amsterdam is de consumptie g hoofd der mannelijke bevolking van jaren liters
#
# rekent men die consuraptio in tti dan pw l oofl der mannelijke bevolking van soja bedrabmfkt men dat dzo en in amsterdam zelfs ent en tf een werkman die slechts in de week verrqitu bp das borrels drinkt verkwist ar n jenever er begw vn ija gcllel iitomsn
#
# het dienstbodenkantoor op de var kenmarkt c te utrecht voor alle manneen vrouwelijke dienstboden is dagelijks geopend
#
# hq telde meer belang in zjjn boeken dan in alle vrouwelijke bekoorlijkheden nog nooit had hij den minsten aandrang tot liefde gevoeld voordat hq hyacinth vaughan had ontmoet
#
# bij da vrouwelijke schare geschiedt dit door de vrouw van den hadjie of ook wel dcor maagden die soembaiaags irjo
#
# hoewel ze het als alle vrouwelijke bedienden droeg namelijk stevig ineen gewrongen en met zilveren haarspeldeu als kondeh chignon opgestoker zoo kon toch dit eenvoudige hoofdtooisel niet beletten dat er achter in den nek en op het voorhoofd enkele weerbarstige lokjes te voorschijn traden van tutschen het glad opgekamde lagere haar
#
# miju gastvrouw gaf hare bevelen omtrent enig naaiwerk aan de meid zoo worden in t algemeen alle vrouwelijke bedienden oud of jong gehuwd of niet in indi genoemd en zag mg spotachtig glimlachend aan toea ze bemerkte dat ik de vrouw zoo oplettend waarnam
#
# derzelver genezende eigenschappen o p s zijn heilzaam zoowel voor ouden als jongen beide van het mannelijk en vrouwe o z w lijk gestacht en in ieder tijdperk van het leven van af de wieg en later zij rh roeijen de zaden uit vau die kwalen die ieder jaar duizenden vroeg ten grave
#
# de bepalingea aangaande het herhalingsonderwijs zijn niet van toepassing op vrouwelijke leerlingen
#
# in verband daarmede geeft de schoolcommissie nu in overweging de avondschooltijaen aan de armen en tusschenscholen to doen vervallen voor zoover deze niet bestemd zijn voor teekenonderwijs of onderwij in de vrouwelijke handwerken
#
# engelnd telt voorzeker nog groote talenten j die op le planken fungeeren zoowel mannelijke i als vrowelijke
#
# c m al date gasten te bedienen heeft men ongeveer mannelijke en even zooveel vrouwelijke dienstboden die kamers hebban in orde te houden
#
# evenals de mannelijke zoo zijn ook de vrouwelijke veroordeelden in klassen gedeell maar de perioden van overgang zijn voor haar korter
#
# derzelver genezende eigenschappen zijn heilzaam zoowel voor ouden als jongen beide van bel mannelijk en vrouwelijk geslacht en in ieder tijdperk van het leven van af de wieg cn lalei dij roeien de zaden uit van die kwalen die ieder jaar zuizenden vroeg ten grave doen dalen
#
# ten bewijze dat de zucht om zich aan den onderwijzersstand te wijden ondanks de verhoogde jaarwedden die aan hoofden hulponderwijzers zijn toegekend in deze streken niet groot is moge ook de niededeeling dienen dat zich van de mannelijke en vrouwelijke adspiranten naar eene acte van bekwaamheid of naar eene aantcekenidg op reeds verkregena acte in het eerste district van gelderland slechts vijf kandidaten naar eene hulponderwijzersacte hebben aangemeld
#
# de verdienstelijke john cuy zegt in zijn verslag betreffende de gevangenis te preston ik moet doen opmerken dat ik in twee jaren mannelijke gevangenen hunne verschillende misdaden of wanbedrijven hoorde toeschrijven aan den drank
#
# voor het aanstaande seizoen worden gevraagd een chef de cuisine tvn f ij kl eu vrouwelijke dies tbooe v adres in persoon of met franco brieven
#
# met een echt priesterlijken en de mannelijke en vrouwelijke candireligieuzen geest bezield was hij een daten slechts vijf voor de hulponderwijvoorbeeld van stichting voor allen die zersakte
#
# hij heeft namelijk aan de vrouwelijke postbeambten plotseling een examen in de nieuwere geographie opgelegd
#
# besluit m lende de voorwaarden van de uitzending van onder zeressen voor de gouvernementsscholen in nedermnd dit besluit in verband met de gunstige regeling der posw van het mannelijk personeel verzekert aan de kolonin e korps uitstekende europeesche onderwyzers aan de lagef soholen in indi en spreekt krachtiger dan alle betoojjf voor den geest waarmede de minieter bezield is
#
# zij heeft een forsche mannelijke stem en over t geheel een mannelijk voorkomen
#
# de hamburger nachrichlen wijst op de huiswet der dynastie osman die voorschrijft dat bjj den dood van een sultjn in turkije de troonopvolger al zijn broeders moet laten dooden en alle mannelijke kinderen der keizerlijke prinsessen onmiddellijk na de geboorte moet doen ombrengen om zijtakken in de erfopvolging te voorkomen
#
# eerie groote opkomst zoowel van de vrouwelijke als de mannelijke leden wrdt vooral bij deze eerste vergadering waarin de grondslag moet worden gelegd voor de werkzaamheden der afdeeling zeer gewenscht
#
# met april komt bij de inrichting der rijksnormaallessen te zwolle beschikbaar een rijksbeurs van voor mannelijke of vrouwelijke kweekelingen in overijssel mits thans wonende buiten de gemeente zwolle
#
# het mannelijk hulppersoneel zeide hij iq in getalsterkte en in stoffelijken zin steeds vooruitgegaan
#
# verhuurkantoor voor alle marine en vrouwelijke dienstboden op de varkenmarkt te utrecht c
#
# daarom vinden wij het zeer verklaarbaar niet alleen dat de oppositie verlangde den kinderen van vrouwelijke lidmaten der kerk het recht tot opname in haar midden ontzegd te zien maar wij vinden dit zelfs in zekeren zin een verblijdend teeken
#
# dit nu is door niemand betwist bet geschil betrof een ander punt zal dit recht ook op hunne kleinkinderen in de vrouwelijke lijn kunnen worden overgedragen
#
# dan toont hij aan dat sedert de ondeugd al zij het dan ook niet als deugd toch zoo behagelijk en aanminnig wordt afgeschilderd de deugd om nog belangstelling te kunnen inboezemen wel het een en ander van de ondeugd moet overnemen hetgeen als ik mij niet bedrieg uw arbeid zoo bijzonder netelig gemaakt heeft is dat gij het vrouwelijk ideaal hooger hebt willen stellen dan de oude tooneelschrrjvers
#
# er wordt gevraagd een mannelijke dienstbode niet boven jaar oud die goed kan r ij d e n en tevens kan melken
#
# vrouwelijke bediende gesenikt om zieken op te passen
#
# vrouwelijke bediende geschikt om zieken op te passen
#
# derzelver genezende eigenschappen zijn heilzaam zoowel voor ouden nis jongen beide van het mannelijk en vrouwelijk gestacht en in ieder tijdperk van het leven van af de wieg en later zij roeijen de zaden uit van die kwalen die ieder jaar duizenden vroeg ten grave doen dalen
#
# ten bewijze dat de zucht om zich aan den onderwijzersstand te wijden ondanks de verhoogde jaarwedden die aan hoofd en hulponderwijzers zijn toegekend in deze streken niet groot is moge ook de mededeeling dienen dat zich van de mannelijke en vrouwelijke adspiranten naar eene akte van bekwaamheid of naar eene aanteekening op reeds verkregene akte in het ste district dezer provincie slechts vijf kandidaten naar eene hulponderwijzersakte hebben aangemeld
#
# jonkheer johan rabo vankeppel met al zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als gerechtigd tot het voeren der titels van baron en barones
#
# johan rabo van keppel met alle zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als gerechtigd tot het voeren der titels van baron en van barones den offic
#
# jl is jonkheer johan rabo van keppel met alle zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als gerechtigd tot het voeren der titels van baron en van barones
#
# derzelver genezende eigenschappen zijn heilzaam zoowel voor ouden als jongen beide van bet mannelijk en vronwelijk geslacht en in ieder tydperk van het leven van af de wieg en later dg roeien de zaden uit van die kwalen die ieder jaar zuizenden vroeg ten grave doen dalen
#
# johan rabo van keppel met al zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als gerechtigd tot het voeren der titels van baron en van barones bij de directie der marine te amsterdam bevorderd tot commies den adjunctcommies j j schikking en tot adj commies de klerk j h v riemens den officier van administratie e kl
#
# johan rabo van keppel met alle zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als geregtigd tot het voeren der titels van baron en van barones bij besluit van dezer heeft z
#
# daily telegraph trok onlangs in een leadingartikel eene parallel tusschen de misdaad in engeland en in frankrijk en brak een lans voor de wil ebeaters door te beweren dat de dronkenschap der vrouwelijke sekse eene hoofdoorzaak is en dat de engelsche vrouw niet de kunst verstaat zooals hare fransche zuster een soort van overwicht op haren man uit te oefenen
#
# in biscaye waar onder de mannelijke bevolking van de tot de jaren evenals in guipuzcoa een nieuwe lichting van bataljons wordt voorbereid beschikken de carlisten op het oogenblik over talrijke strijdkrachten met geschut
#
# f hots oud jaren dochter tan engelenburg voornamen en ouderdom onbekend fuselier muller toornamen onbekend oud jaren korporaal m m mauratie oud jaar dochter o keegeri oud jaren vrouwelijk p c vergeijlen oud jaren weesjongen j f tan eek oud jaren sergeant j saban oud jarsn jongen e d hukom oud jaren jongen
#
# h aifmue i q vrouwelijk
#
# duizcnde vrouwelijke robben zag men zwemmen blijkbaai zoekende naar een plek om hare jongen te kunnen werpen op de ijsschollen waarop de jonge robben hun voedsel garnalen vinden
#
# i dooreen toeval werd de vrouwelijke christelijke associatie bekeud met haar toestaud
#
# de gemeenteiaad van rotterdam heel met het oog op het bestaande gebrek aan hulponderwijzers besloten eene proef te nemen met de aanstelling van vrouwelijk hulppersoneel op de scholen
#
# is jonkheer joban liabo van keppel met alle zijne wettige zoo mannelijke als vrouwelijke afstammelingen erkend als geregtigd tot het voeren der titels van baron en van barones
#
# toespraken aan jeugdige i vrouwelijke lidmaten
#
# als leden van het kerkge nootschap komen tot bepaling van het aantal slechts in aanmerking meerder hl jarige zelfstandige mannelijke personen
#
# zijn hooge gestalte beheerschte alle kringen waar hij verscheen en dwong ontzag door de mannelijke schoonheid door de waardige manieren
#
# met april komt bij de inrichting der riiksnormaallessen te zwolle beschikbaar een rijksbetjrs van voor mannelijke of vrouwelijke kweekelingen in overijssel mits thans wonende buiten de gemeente zwolle
#
# ten allen ttjde heb ik slechts lof over gehad voor de schoone opvatting hunner taak en voor hun mannelijke zelfverloochening
#
# jll vrouwelijk i l
#
# in het eerste schooldistrict der provincie gelderland bevinden zich voor de aanstaande onder wijzersexamens onder de mannel jke en vrouwelijke candidaten slechts vijf voor de hulponde wijzersakte
#
# de bevolking van overijssel is gedurende toegenomen met zielen waarvan van het mannelijk en van het vrouwelijk geslacht en beliep op januari m vr dus samen
#
# het aantal overledenen beliep waarvan van het mannelijk en van het vrouwelijk geslacht dat der huwelijken
#
# hetzelfde directorium geeft ook een nauwkeurig verslag van de mannelijke en vrouwelijke religieusen die aldaar gevestigd zijn mvindt er benedictijnen trappisten serviten franciscanen dominicanen enz
#
# oigens een derde gevoelen is het voldoende eene rijksasting op de honden te heffen en wel eene hoogere op het ueiijk dan op het vrouwelijk geslacht naar sommiger deel behoorde een deel der opbrengst aan de gemeenten worden uitgekeerd opdat deze tot het beoogde doel te der zouden medewerken
#
# bij sommige troepjes vonden we ook vrouwelijke exemplaren die er mede lustig op toe bliezen
#
# van de normaalleasen werd gebruik gemaakt door hulponderwijzers en mannelijke kweekelingen hulponderwn zeressen en vrouwelijke kweekelingen
#
# op december waren aan de gemeentescholen behalve de hoofdonderwijzers werkzaam hulponderwijzers hulponderwijzeressen en vrouwelijke en mannelijke kweekelingen
#
# in de vereciiiili slaten zijn iurigliugen vpn onderwijs waaronder openhare v iei fs i onderwijzers eu t onderwijzeressen en manlijke en st vrouwelijke leerlingen
#
# voor ouden als jongen beide van het mannelijk en vrouwelijk gestacht en in ieder tijdperk van het leven van af de wieg en later zij roeijen de zaden uit van die kwalen die ieder jaar duizenden vroeg ten grove doen dalen
#
# deze verklaring moesten alle geestelijken zoowel mannelijke als vrouwelijke
#
# de vereeniging draagt aan een mannelijk en een vrouwelijk lid het meer bijzonder oppertoezicht over deu knaap op zoo mede de voorziening in zijne behoeften aan kleederen en geneeskundige hulp en het toezicht over de verdere verzorging
#
# voorts besloten onder die voorwaarden ook vrouwelijke kweekelingen toe te laten en den hoofdonderwijzers eene gratificatie van te verleenen voor iederen kweekeling die onder hunne leiding met goed gevolg examen als hulponderwijzer of hulponderwijzeres aflegt
#
# nadat de voorzitter met een enkel woord zijne vreugde over de groote spkomst van belangstellenden had te kennen gegeven werd het verslag over voorgelezen waaruit o a bleek dat de vereeniging thans zoo mannelijke als vrouwelijke leden telt en begunstigers in hoofdzaak tracht zij door middel van de onderwijzers der jeugd hare denkbeelden omtrent de dierenbescherming ingang te doen vinden
#
# de mannelijke en vrouwelijke leden der door z eetw
#
# in het op te richten gebouw zal plaats wezen voor vrouwelijke studenten en professoren
#
# dion tijd en de afgunst van baar vrouwelijke collega s ve haar geluk moet nog al groot geweest zfjn
#
# derzelver genezende eigenschappen zijn heilzaam zoowel voor onden als jongen beide van het mannelijk en vrouwelijk geslacht en in ieder tijdperk van bet leven van af de wieg en later dij roeien de zaden uit van die kwalen die ieder jaar zuizenden vroeg ten grave doen dalen
#
# toen de russische regeering nu ruim een jaar geleden haar ukase tegen de vrouwelijke studenten te zrich uitvaardigde beloofde zij tegelijkertijd in rusland zeil gelegenheid tot wetenschappelijke ontwikkeling van de vrouw te geven
#
# het doel der inrichting zal viervoudig zijn het onschadelijk maken van de werking die t bezoeken van den paedagogischen cursus aan de universiteiten op de jonge dames heeft leeraressen te verkrijgen voor de vrouwelijke gymnasia in rusland desnoods alleen voor de lagere en middelbare klassen het verkrijgen van gouvernantes ten bate van familien wier kinderen tot aan de middelklassen der gymnasia voorbereid moeten worden en dames voor te bereiden voor den medischen cursus aan de universiteiten
#
# de door de regeering ingestelde commissie wier beraadslaging tot de bovengenoemde voorstellen heeft geleid is nog van meening dat ook de oude talen in de vrouwelijke gymnasia als vakken van onderwijs moeten opgenomen worden
#
# is beschikbaar eene rijkstoelage van s jaars voor mannelijke of vrouwelijke kweekelingen in overijssel mits thans wonende buiten de gemeente deventer
#
# te rotterdam is gisterenavond in de vergadering van het iv sdepartement de discussie begonnen over het voorstel om een huur en verhuurkantoor voor vrouwelijke dienstboden op to richten
#
# hendrik ruljs mannelijk ongehuwd s jaar gerbrand nijland ml
#
# ristori benevens al de vrouwelijke zoo wel als de mannelijke leden van haar gezelschap in rouwkleederen gedoscht de lijkkoets te voet volgden
#
# siob volgens de als gewoonlijk door de gemeentebesturen opgemaakte tabellen bedroeg iiilusschcn de wettige bevolking op december b mannelijke en vrouwelijke tezamen ingezetenen
#
# dit cyfer duidt in vergelijking met dat van de wettige bevolking op den december eene vermeerdering aan van personen waarvan mannelijke en vrouwelijke
#
# en vrouwelijke gevangenen
#
# nog waren onderde geboorten begrepen twee wettige drielingen ieder bestaande uit twee kinderen van het mannelijke en een kind van het vrouwelijke geslacht als eene te vlissingen en eene tearnemuiden
#
# het getal der overledenen in betrekking tot de wettige bevolking bedroeg personen waarvan tot het mannelijke eu tot het vrouwelijke geslacht behoorden
#
# de mannelijke inwoners voegden zich bij de manschappen van garibaldi
#
# algemeen worden zij beschouwd als het beste geneesmiddel voor de ziekte der vrouwelijke kunne nooit missen zij de verlangde uitwerking en verzwakken daarbij geenszins het gestel
#
# eene vrouwelijke javaansche bediende de besta getuigschriften kunnende produceren wenschte ter oppassing eener naar i indib vertrekkende familie als lijfmeid mede te gaan
#
# akwoorrnroek jffr bevattende eene verzameling van mannelijke en vrouwelijke zelfstandige naamwoorden en van woorden die met cc ti en g moeten ven worden ten dienste van hen die goed ncdcrduitsch wenschen te schrijven
#
# de mannelijke bevolking des rijks van den ouderdom van is tot jaren uit welke de militie wordt zamengesteld telde in het jaar isoo ongeveer in in en thans kan zij op hoofden gesteld worden
#
# mannelijke vrouwelijke te zamen
#
# de feitelijke bevolking telde mannelijke vrouwelpe te zamen
#
# de sterfte in deze provincie beliep personen namelijk van het mannelijk en van het vrouwelijk geslacht
#
# mannelijke rouwelijke te taroefl
#
# in telde men iv deie provincie tle volgende terfgeratlen op de we lelijke bevolking van het mannelijk geslacht vrouwelijk totaal
#
# behoude god hem nog lange jiren in ons midden in die mannelijke kracht die hem in zijn hoogen ouderdom nog jeugdigen moed en jeugdige werkzaamheid verleent
#
# beliep mannelijke vrouwelijke zamen
#
# de feitelijke bevolking telde mannelijke vrouwelijk zamen
#
# hetgesigt waa bijna kinderachtig in doselfs volmaak te eenvoudigheid en reinheid maar toch lag er taatbenulenheid in kot settcn van den mond en vrouwelijke waardigheid in liet pan voo
#
# en hij moet mijn troetelkimt zijn want clifton is zoo jroot en mannelijk dat hem die naam niet bevallen zou
#
# beuep mannelijke vrouwelijke zamen
#
# de feitelijke bevolking telde mannelijke vrouwelijke terne
#
# behoade god hem nog lange jaren in ons midden in die mannelijke kracht die bern in zijn hoogen ouder dom nog jeugdigen moed en jeugdige werkzaamheid verleent
#
# ristori benevens al de vrouwelijke zoowel als de mannelijke leden van haar gezelschap in rouwkleederen gedoscht de lijkkoets te voet volgden
#
# daar achter stonden met ontblootcn hoofde de gezamenlijke kunstbroeders van den overledcue op wier mannelijk gelaat diepe smart te leien stond ook op het gelaat der talrijke verdere aanwezigen stond opregte deelneming te lezen
#
# siebold e von handboek over de kennis en genezing dor ziekten van het vrouwelijk geslacht
#
# j van geringen omvang die weinig stof tot opmerkingen p fjjiig jj er zijn ook gemeenten waar de verpligting tol het beurt van nachtwacht aan de mannelijke ingezetenen van zekere eene verordening is opgelegd
#
# ik heb met genoegen gezien dat de oude neiging van het engelsche volk voor mannelijke spelen en het jagersbedrgf door uwe vereeniging eene meer degelijke rigting heeft gekregen en tot een hulpwerktuig voor de handhaving der veiligheid van ons gemeenschappelijk vaderland zal kunnen dienen
#
# behoude god hem nog lange jaren in ons midden in die mannelijke kracht die hem in zijn hoogen ouderdom nog jeugdigen moed en jeugdige werkzaamheid verleent
#
# aan sommivrouwelijke gevangenen werd naai en breiwerk gegeven daarenboven hebben enkele mannelijke gevangenen zich onledig gehouden met het kieureu van prenten waarmede bij gestadig werk een goed loon kan worden verdiend
#
# ook hebben wederom a mannelijke gevangenen gedurende eenigen tijd werk gevonden met het doorknippen van ctiquettes voorwijuflesschen
#
# met genoegen heb ik gezien do wijze waarop dank zij uwe vereeniging deoude hartstogt van het engelsche volk voor mannelijke spelen en het jagtbedrjjf gerigt is naar een belangrijker doel en veranderd in een hulpwerktuig om de veiligheid van ons gemeenschappelijk vaderland ongeschonden te handhaven
#
# laak gesteld heeft om een blijvenden duur te verschaften aan ij pende magt welke uitsluitend tot een defensief doel bestemd b vi e j met genoegen gezien dat de oude neiging van het engelsche h w mannelijke spelen en het jagersbedrijf door uwe vereeniging ksu
#
# ristori benevens al de vrouwelijk zoowel als de mannelijke leden van haar gezelschap in rouw kleederen gedoscht de lykkoets te voet volgden
#
# daar achter stonden met ontblooien hoofde de gezamenlijke kunstbroeders van den afgestorvene op wier mannelijk gelaat diepe smart te lezen stond ook op het gelaat der talrijke verdere aanwezigen st nd opregt e deelneming te lezen
#
# bij eene fatsoenlijke protestantsche familie nabij s bosch bestaat gelegenheid tot kost en inwoning met of zonder huisselijk verkeer voor een heer of eene dame de laatste zou desverkiezende in haar eigen voordeel in vrouwelijke handwerken kunnen behulpzaam wezen
#
# aan het dfil namen behslve de troepen ook de werklieden mannelijke en vrouwelijke der hoofdstad deel
#
# ten jare was de verhouding der mannelijke tot de vrouwelijke bevolking des lands als het gevolg der langdurige oorlogen destijds gevoerd in was de verhouding veel gunstiger namelijk
#
# in stond de mannelijke tot de vrouwelijke bevolking in noorwegen als
#
# in de maand junij jl zijn in de registers van den burgerlijken stand ingeschreven te middelburg huwelijken geboorten als zoons en dochters si sterfgevallen als van het mannelijk en van het vrouwelijk geslacht
#
# te vlissingen huwelijken geboorten als zoons en is dochters sterfgevallen van het mannelijk en van het vrouwelijk geslacht
#
# te zierikzee huwelijken geboorten als g zoons en dochters sterfgevallen van het mannelijk en van het vrouwelijk geslacht
#
# te goes huwelijken geboorten als zoons en dochters van het mannelijk en van het vrouwelijk geslacht
#
# na afloop der godsdienstige plegiigheid hield de koning eene revue over de nationale garde der hoofdstad eu omliggende gemeenten en over een gedeelte van het leger aan het dfil namen behalve de troepen ook de werklieden mannelijk en vrouwelijk der hoofdstad deel
#
# begrip van het fransche regt ten gebruike van het vrouwelijk geslacht thans heeft eene vrouw mw
#
# lavenue te anteuil een cursus geopend waarin het fransche regt voor zooverre het betrekking heeft op het vrouwelijk geslacht wordt onderwezen
#
# het doel dat de stichtster van deze soort van akademie zich voorstelt is voornamelijk om de vrouwen te verlossen uit de handen van sommige zaakwaarnemers die al hun best doen om misbruik te maken van de onwetendheid waarin de vrouwen verkeeren ten opzigte van de regten welke zij volgens de wet bezitten iets waaraan de meestal bekrompen opvoeding van het vrouwelijk geslacht schuld is
#
# in het eerstgenoemde ontvangen wij twaalf net uitgevoerde kaartjes die ons de verschillende landen van het keizerrijk oostenrijk ten opzigte van de sterkte der bevolking de verhouding van het mannelijk tot het vrouwelijk geslacht die der onderscheidene volkstammen en der onderscheidene geloofsbelijdenissen tot de geheele bevolking alsmede ten opzigte van het meest uitgeoefende bedrijf
#
# het onderwijs omvat alles wat tot eene beschaafde vrouwelijke opvoeding behoort en de voorwaarden zijn matig gesteld terwijl de gezonde ligging dezer plaats genoegzaam bekend is
#
# in dc volgende maand zal nog een schip met vrouwelijke emigranten naar australi v p v t r k en dezer dagen werden hier schilderijen verkocht het voornaamste gedeelte uitmakende van de verzameling van sir culling eardley waarvan de navolgende bijzonder hooge prijzen opbragten davidteniers de jongere de schilderijgalerij van den aartshertog leopold te brussel guinjes dezelfde zijn atelier guinjes e w cooke gezigt bij dc goodwinsands guinjes murillo de onbevlekte ontvangenis guinjes lob claude lorrain landschap guinjes j b weemx landschap guinjes a van
#
# ik hoop de tijd te beleven waarop alle volken meerderjarig zullen zijn dat is dat zij den mannelijken leeftijd zuilen hebben bereikt en vrijelijk hunne eigene opperhoofden kiezen zoo als frank rijk mij heeft gekozen
#
# bij den boekverkooper c de rooy te delft bij fatsoenlijke protestantsch dames uit den deftigen burger stand te dezer stede bestaat gelegenheid om de geheele verzorging op zich te nemen van een of twee hinderen hefst meisjes van goeden huize om haar alle vrouwelijke handwerken benevens alles wat tot eene nette huishouding behoort te leeren
#
# siebolb e von handboek over dc kennis en genezing der ziekten van het vrouwelijk geslacht
#
# uit afrika wordt gemeld dat de kossohs den junij een verraderlijken aanval hebben gedaan op de inwoners van magbelli bij gape goast gastle terwijl de mannelijke bevolkingen voor het grootste gedeelte afwezig was
#
# de mannelijke inwonen voegden zich bij de manschappen van gnribaldi
#
# het meerendeel der mannelijke bevolking waa afwezig en alleen de ouden vau dagen en gebrekkigen bevonden zich in de stad
#
# even als deze plegtigheid geopend werd werd dezelve met koof gezang gesloten waarna wij verrassend onthaald werden op eekeur van handschriften en handteekeningen terwijl door een ui gelezen vrouwelijk publiek de onderscheidene handwerken met roe werden overladen
#
# het repertoire van het grand tfcatre des varits van den heer van lier jz waarop voorkomen stukken zooals paillas de tijgerjager de kaartlegster eene vrouwelijke monto christo enz die meest allen elders met succes opgevoerd en ook velen onzer stadgenooteo niet onbekend zyn belooft gedurende deze kermis weder vele genotryke avonden en daar de heer van lier voor de nastukken meerendeels de aardigste vaudevilles heeft uitgekozen zal zyn thatre gewis wederom een druk bezoek ten deel vallen
#
# met geen enkel woord wordt daarin van frankrijk gewag gemaakt maar elke zinsnede elke regel is een mannelijk energiek protest tegen eiken aanval op de belgische nationaliteit
#
# het grootste gedeelte der mannelijke bevolking was afwezig terwijl alleen de ouden en zieken in de stad waren
#
# overleden t a e kremer mannelijk j geh
#
# v munnekeburen j j groenewoud mannelijk jaren van spanga
#
# in het gesticht meerenberg bestaat terstond gelegenheid tot plaatsing van eenige mannelijke en vrouwelijke bedienden
#
# bcnoodisd voor het europeesci personeel drie mannelijke uij o slc bestemd om den administrateur in het huishoudelijk belleer der inrigting bij te staan en om buiten de schooluren in het houden van toezigt behulpzaam te zijn
#
# ook bestaat behoefte aan eene vrouwelijke bediende bestemd om het oppertoeigt o eer de wascli het naaijen enz
#
# dit althans ware mannelijker geweest dan het daatoe zigtbaar opzoeken van allerlei tijdverspiilende middelen en dit te meer omdat gelijk beden een onzer liberale bladen de n r
#
# benoodigd voor het europeesch personeel drie mannelijke suppoosten bestemd om den administrateur in het huishoudelijk beheer der inrigting bij e stam en om buiten de schooluren in het lm len van toezigt behulpzaam bij voorkeur zal de aandacht gevestigd worden op euro ie onderofficieren mus voorzien van bewijzen van goed zedelijk gedrag
#
# ook bestaai behoefte aan eene vrouwelijke bediende bestemd om het oppertoezigt over de wasch het naaijen enz
#
# daardoor ontving een groot getal van kinderen uit den minderen stand by kosteloos onderwijs in de noodigste vrouwelijke handwerken ook christelijke beschaving en opleiding terwijl onbemiddelde dames van fatsoenlijken stand eene stille ondersteuning vonden als hare handwerken onder kiesche geheimhouding werden overgenomen tot verkooping of verloting
#
# de jongen is in heehien s eene der groote slangen boa conslriclor in den dierentuin le amsterdam heeft op eenmaal vierentwinlig jongen gewarpen deze fraaije slang leelde reeds ongeveer jaren iv de diergaarde en werd ongeveer een jaar gegeleden met een mannelijk voorwerp te zamen gebragt dat nu uit de kooi is weggenomen om de moeder welke hare jongen zorgvuldig bewaakt meer plaatsruimte te geven
#
# deze fraaije slang leefde reeds ongeveer negen jaren in de diergaarde en werd ongeveer eenjaar geleden met een mannelijk voorwerp te zamen gebrast dat nu uit de kooi is weggenomen om de moeder welke hare jongen zorgvuldig bewaakt meer plaatsruimte te verschaffen
#
# de geestdrift voor de zaak der vrijwillige wapenen beeft zich ook aan het vrouwelijk geslacht medegedeeld
#
# twee mannelijke gevangenen overleden in het gesticht
#
# aan het schoolonderwijs in de gevangenis te middelburg werd door mannelijke en vrouwelijke gevangenen en wel drie malen s weeks deelgenomen
#
# door mannelijke en vrouwelyke gevangenen te middelburg werd godsdienstig onderwijs genoten terwijl voor de hervormden en roomschkatholieken eenmaal s weeks godsdienstoefening werd gehouden
#
# in het gesticht meerenberg bestaat terstond gelegenheid tot plaatsing van eenige mannelijke en vrouwelijke dedienden
#
# en werd ongeveer een jaar geleden met een mannelijk voorwerp te zamen gebragt dat nu uit de kooi is weggenomen om de moeder welke bare jongen zorgvuldig bewaakt meer plaatsruimte te verschaften
#
# het meerendeel der mannelijke bevolking was afwezig en alleen de ouden van dagen en gebrekkigen bevonden zich in de stad
#
# kapitein klinge en korporaal specht trokken de grimmigste geiigten ran de wereld om den delinquent tot eeue mannelijke standvas tigheid aan te zetten maar ok dezo manoeuvre mislukte
#
# willem hl benoodigd voor bei europeesch personeel drie mannelijke suppoosten bestemd om den administrateur in het huishoudelijk beheer der inrigng bij te staan en om buiten de schooluren in het houden van toezigt behulpzaam te zijn
#
# ook beslaat behoefte aan eene vrouwelijke bediende bestemd om liet oppertoczigt over de wasch het naaijen j eii te houden
#
# om nu verder tegen de bloedwraak der overigen beveiligd te zijn gaf prins danielo bevel dal alle mannelijke leden der familie zelfs tot in den versten graad van bloedverwantschap ontwapend en daarna mei unne over de grenzen zouden gebragt worden
#
# de mannelijke inwoners hebben zich bij
#
# endden u u k ll te terscidene der vrouwelijke maria dankte haar en keerde met eene hulpbende van twee vrouwen naar de keuken terug
#
# langs den wand der zaal waren de teekeningen der leerlingen naar de natuur en naar voorbeelden alsmede eenige vrouwelijke handwerken ten toongesteld
#
# hij had anders hielen daar wel iets hardere uitdrukkingen gewenscht want als de belangen van rotterdam niet in acht genomen zijn dan mag zijns oordeels de gemeenteraad van rotterdam in een adres aan de tweede kamer zulks wel in goede mannelijke en niet al te zachte taal te kennen geven
#
# bij de erven j tijl te zwolle komt van de pers de vijfde druk van kroeze ramaker zakwoordnboxskjei bevattende eene verzameling van mannelijke en vrouwelijke zelfstandige naamwoorden en van woorden die met et ei en g moeten geschreven worden ter dienste van hen die goed nederduitsch wenschen te schrijven
#
# doch de nieuwsgierigheid had de overhand en toen een smid het open slak vond men behalve het gewone sierlijke gereedschap voor vrouwelijke handwerken eene kleine gehekelde beurs met eenig goud geld en een visitekaartje op hetwelk gedrukt stond baron hallrr ziet gij wel
#
# dachtde griffier en hield een overzigt over zijne vrouwelijke kennissen inde residentie
#
# de mannelijke inwoners voegden zich bij de
#
# daardoor ontving een groot getal van kinderen uit den minderen stand bij kosteloos onderwijs in de noodigste vrouwelijke handwerken ook christelijke beschaving en opleiding terwijl onbemiddelde dames van fatsoenlijken stand eene stille ondersteuning vonden als hare handwerken onder kicsche geheimhouding werden overgenomen tot verkouping of verloting
#
# men vraagt om eencn zieken heer te passen eencn mannelijken bediende p g wetende met zieken om te gaan en van goede getuigenissen omtrent zedelijk gedrag voorzien zich te adresseren bureau handelsblad onder letter v w
#
# overleden t hanke vrouwelijk weken van noordwolde
#
# gymnasium willem bcnoodlgd voor het europeesch peroo drie mannelijke suppoosten
#
# vau gez de kl met vier kinderen eu eene javaansche vrouwelijke bediende jorntsma offic
#
# eo eene javaansche vrouwelijke bedi jorritsina offic
#
# daardoor ontving een groot getal van kinderen uit den minderen stand bij kosteloos onderwijs in do noodigste vrouwelijke handwerken ook christelijke beschaving en opleiding terwyl onbemiddelde dames van fatsoenlijken stand eene stille ondersteuning vonden als hare handwerken onder kiesehe geheimhouding werden overgenomen tot verkooping of verloting
#
# aan het dfil namen behalve de troepen ook de werklieden mannelijk en vrouwelijk der hoofdstad deel
#
# hetge schrift biedt ons in helderen en mannelijken stijl eene beschouwing van den toestand des hoogeren levensinfrankrijk en is als teeken des tijds de behartiging onwaardig overal waar het alvermogen van den staat het leven des volks tot de behartiging van enkel stoffelijke belangen zoekt zamen te
#
# en ecne javainsche vrouwelijke brdieudc jotriuma ofc
#
# godsdienst om onderrigt aan een jong meisje te geven in het schrijven in de taalkunde en zoo mogelijk in het fransch en in de beginselen van vrouwelijke handwerken
#
# i een ouderloos meisje circa jaren oud vau de hervormde godsdienst gexamineerd in de hollandsclie fransche en engelsche talen en in vrouwelijke handwerken zag zich gaarne zoo spoedig mogelijk geplaatst als jongste sca t op eene kostschool des noods zonder salaris
#
# i die van zijne bekwaamheid en gedrag voldoende h fii adres aan hct bureau der utrcchtsche courant o franc lf ecnc juevbouw p g gexamineerd ft k l benevens in de moderne talen en vrouwelijke d noi cyy getuierschriften voorzien wenschte met ecnc lm ter
#
# de afgebrande fabriek verschafte werk aan werklieden zoo mannelijke als vrouwelijke
#
# w j de vries mannelijk jaren weduwenaar van idzard j l westerbeek mannelijk jaren van noordwolde
#
# j hogeling mannelijk jaar van idzard
#
# h d van der molen vrouwelijk jaren gehuwd van oldeholtwolde
#
# s j kuperus vrouwelijk jaren weduwe van njjhultwolde j k w huisman mannelijk jaren gehuwd van oldelamer j van d
#
# v eene jufvrouw die eene beschaafde opvoeding genoten heeft bekwaam om in de beginselen der hollandsche en fransehe taal het rekenen de muzijk en alle vrouwelijke handwerken onderwijs te geven en die tevens niet ongenegen zou zijn eenige assistentie in de huishouding te verkenen wenschte zich zoo spoedig mogelijk geplaatst te zien hetzij als gouvernante bij jonge kinderen hetzij als jufvrouw van gezelschap
#
# den bsten dezer overleed op zijn slot te grodziec graaf wladislaw jan nepomucen bielinski de laatste mannelijke afstammeling van deze linie
#
# in de eerstgenoemde stad werd het grootste gedeelte der mannelijke bevolking vermoord
#
# het toestemming van den beer resident van soerabaya geopend heden arond zaturdtg julij en eiken arond der volgende week wet een groot pebogramai a van wonderen van rijkunst waarin zullen optreden de gstoote iiernandez de eerste rijder der wereld en hetgeileele gezelschap mannelijke eh vuwejke artistes
#
# de voorstellingen werden gisteren avond gesloten met de vrouwelijke monlechristo vroeger alhier met goed gevolg vertoond en waarin bijzonder mevr
#
# cn eciio javaansche vrouwelijke bediende jorrilsnia offic

# %% [markdown]
# ## Document Embeddings

# %%
document_embeddings = DocumentPoolEmbeddings(
    embeddings=[flair_forward_embedding,flair_backward_embedding])

# %%
X = []
labels,colors = [],[]

context = 3
for period, raw_sents in sents2year.items():
    for raw_sent in tqdm_notebook(raw_sents[:100]):
        sentence = Sentence(raw_sent)
        document_embeddings.embed(sentence)
        X.append(sentence.get_embedding().detach().numpy())
        colors.append(names2colors[period])
        labels.append(' '.join([t.text for t in sentence.tokens if len(t.text) > 5 ][:5]))
# Out:
# HBox(children=(IntProgress(value=0, max=60), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=68), HTML(value='')))

# %%
tsne = TSNE(n_components=2, random_state=0,metric='cosine')
X_2d = tsne.fit_transform(X)

# %%
fig = plt.figure(figsize = (30,50))

for i,x in enumerate(X_2d):
    plt.scatter(X_2d[i, 0], X_2d[i, 1],c=colors[i])
    plt.annotate(labels[i], (X_2d[i, 0], X_2d[i, 1]),size=14)
    
    
plt.show()
fig.savefig("document_vectors.pdf", bbox_inches='tight')
