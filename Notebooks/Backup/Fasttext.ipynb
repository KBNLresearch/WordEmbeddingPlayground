# %% [markdown]
# # FastText in Python

# %%
from zipfile import ZipFile
from joblib import parallel_backend
import multiprocessing
import nltk.data
from lxml import etree
from io import StringIO,BytesIO
import re
import logging
from utils import *
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Training and saving a model

# %%
sentences = SentIterator("./data/kranten_pd_1875-6.zip")

# %%
from gensim.models.fasttext import FastText 
model = FastText(size=100, window=5, min_count=10)
model.build_vocab(sentences=sentences)
total_examples = model.corpus_count
print(total_examples)
model.train(sentences=sentences, total_examples=total_examples, epochs=5)
# Out:
# 2019-07-19 11:43:05,086 : INFO : resetting layer weights
# 2019-07-19 11:43:12,591 : INFO : collecting all words and their counts
# 2019-07-19 11:43:16,968 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-07-19 11:43:17,523 : INFO : PROGRESS: at sentence #10000, processed 107717 words, keeping 21357 word types
# 2019-07-19 11:43:18,125 : INFO : PROGRESS: at sentence #20000, processed 229908 words, keeping 36060 word types
# 2019-07-19 11:43:18,698 : INFO : PROGRESS: at sentence #30000, processed 347621 words, keeping 49719 word types
# 2019-07-19 11:43:19,290 : INFO : PROGRESS: at sentence #40000, processed 467061 words, keeping 62003 word types
# 2019-07-19 11:43:19,847 : INFO : PROGRESS: at sentence #50000, processed 572439 words, keeping 72840 word types
# 2019-07-19 11:43:20,438 : INFO : PROGRESS: at sentence #60000, processed 694126 words, keeping 83889 word types
# ...

# %%
path = "./models/kranten_pd_1875-6_model.fasttext"
model.save(path)
# Out:
# 2019-07-19 13:36:34,357 : INFO : saving FastText object under ./models/kranten_pd_1875-6_model.fasttext, separately None
# 2019-07-19 13:36:34,358 : INFO : storing np array 'vectors' to ./models/kranten_pd_1875-6_model.fasttext.wv.vectors.npy
# 2019-07-19 13:36:34,618 : INFO : storing np array 'vectors_vocab' to ./models/kranten_pd_1875-6_model.fasttext.wv.vectors_vocab.npy
# 2019-07-19 13:36:34,859 : INFO : storing np array 'vectors_ngrams' to ./models/kranten_pd_1875-6_model.fasttext.wv.vectors_ngrams.npy
# 2019-07-19 13:36:36,591 : INFO : not storing attribute vectors_norm
# 2019-07-19 13:36:36,592 : INFO : not storing attribute vectors_vocab_norm
# 2019-07-19 13:36:36,593 : INFO : not storing attribute vectors_ngrams_norm
# 2019-07-19 13:36:36,593 : INFO : not storing attribute buckets_word
# 2019-07-19 13:36:36,594 : INFO : storing np array 'syn1neg' to ./models/kranten_pd_1875-6_model.fasttext.trainables.syn1neg.npy
# ...

# %% [markdown]
# ## Loading a model

# %%
model = FastText.load(path)
print(model)
# Out:
# 2019-07-19 13:36:41,786 : INFO : loading FastText object from ./models/kranten_pd_1875-6_model.fasttext
# 2019-07-19 13:36:41,787 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-07-19 13:36:42,097 : INFO : loading wv recursively from ./models/kranten_pd_1875-6_model.fasttext.wv.* with mmap=None
# 2019-07-19 13:36:42,098 : INFO : loading vectors from ./models/kranten_pd_1875-6_model.fasttext.wv.vectors.npy with mmap=None
# 2019-07-19 13:36:42,184 : INFO : loading vectors_vocab from ./models/kranten_pd_1875-6_model.fasttext.wv.vectors_vocab.npy with mmap=None
# 2019-07-19 13:36:42,328 : INFO : loading vectors_ngrams from ./models/kranten_pd_1875-6_model.fasttext.wv.vectors_ngrams.npy with mmap=None
# 2019-07-19 13:36:43,489 : INFO : setting ignored attribute vectors_norm to None
# 2019-07-19 13:36:43,491 : INFO : setting ignored attribute vectors_vocab_norm to None
# 2019-07-19 13:36:43,493 : INFO : setting ignored attribute vectors_ngrams_norm to None
# ...

# %%
query = 'vrouw'
print(query in model.wv.vocab)
model.most_similar(query,topn=20)
# Out:
# True
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# [('mvrouw', 0.9523746967315674),
#  ('mavrouw', 0.9415721297264099),
#  ('movrouw', 0.9399460554122925),
#  ('buurvrouw', 0.9195867776870728),
#  ('vrouwj', 0.9192215204238892),
#  ('vrouwi', 0.9185271263122559),
#  ('vrouwan', 0.911611020565033),
#  ('vrouwlief', 0.9058151245117188),
#  ('vrouwl', 0.9015740156173706),
#  ('evrouw', 0.8959425687789917),
#  ('kraamvrouw', 0.8888833522796631),
#  ('naaivrouw', 0.8807156085968018),
#  ('vrouwvolk', 0.8744056224822998),
#  ('jonkvrouw', 0.87418532371521),
#  ('huisvrouw', 0.8714870810508728),
#  ('moeder', 0.8693599700927734),
#  ('mejonkvrouw', 0.868295431137085),
#  ('mejnfvrouw', 0.8659549951553345),
#  ('ufvrouw', 0.8636929988861084),
# ...
