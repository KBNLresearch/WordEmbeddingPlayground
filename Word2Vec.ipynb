# %% [markdown]
# # Word2Vec in Python

# %%
from zipfile import ZipFile
from joblib import parallel_backend
import multiprocessing
import nltk.data
from lxml import etree
from io import StringIO,BytesIO
import re
import logging
from utils import *
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Training and saving a model

# %%
sentences = SentIterator("./data/kranten_pd_1875-6.zip")

# %%
from gensim.models.word2vec import Word2Vec 
model = Word2Vec(size=100, window=5, min_count=10)
model.build_vocab(sentences=sentences)
total_examples = model.corpus_count
print(total_examples)
model.train(sentences=sentences, total_examples=total_examples, epochs=5)
# Out:
# 2019-07-19 15:55:59,131 : INFO : 'pattern' package not found; tag filters are not available for English
# 2019-07-19 15:55:59,136 : INFO : collecting all words and their counts
# 2019-07-19 15:56:03,123 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-07-19 15:56:03,654 : INFO : PROGRESS: at sentence #10000, processed 107717 words, keeping 21357 word types
# 2019-07-19 15:56:04,223 : INFO : PROGRESS: at sentence #20000, processed 229908 words, keeping 36060 word types
# 2019-07-19 15:56:04,808 : INFO : PROGRESS: at sentence #30000, processed 347621 words, keeping 49719 word types
# 2019-07-19 15:56:05,376 : INFO : PROGRESS: at sentence #40000, processed 467061 words, keeping 62003 word types
# 2019-07-19 15:56:05,922 : INFO : PROGRESS: at sentence #50000, processed 572439 words, keeping 72840 word types
# 2019-07-19 15:56:06,478 : INFO : PROGRESS: at sentence #60000, processed 694126 words, keeping 83889 word types
# ...

# %%
path = "./models/kranten_pd_1875-6_model.word2vec"
model.save(path)

# %% [markdown]
# ## Loading a model

# %%
model = Word2Vec.load(path)
print(model)

# %%
query = 'vrouw'
model.most_similar(query)
